# %%
import pandas as pd
import json 
df=pd.read_excel(r'C:\Users\hbhat\OneDrive\Desktop\VScode\Capstoneproject3\Datset\chennai_cars.xlsx')
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
# Data processing of unstructured data into structured data by splitting data in the new car detail column into specific columns
df2 = df.copy()
df2['new_car_detail'] = df2['new_car_detail'].apply(lambda x : dict(eval(x)))
new_car_detail = df2['new_car_detail'].apply(pd.Series)
print("Length of new_car_detail", len(new_car_detail))
new_car_detail
# Out:
# Length of new_car_detail 1419
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# ...

# %%
# Checking for null records 
new_car_detail.isnull().sum()
# Out:
# it                     0
# ft                     0
# bt                     0
# km                     0
# transmission           0
# ownerNo                0
# owner                  0
# oem                    0
# model                  0
# modelYear              0
# centralVariantId       0
# variantName            0
# price                  0
# priceActual            0
# priceSaving            0
# priceFixedText      1419
# trendingText           0
# dtype: int64

# %%
# Data processing of unstructured data into structured data by splitting data in the new car overview column into specific columns
df2 = df.copy()
df2['new_car_overview'] = df2['new_car_overview'].apply(lambda x : dict(eval(x)))
df4 = df2['new_car_overview'].apply(pd.Series)

df5 = df4.explode('top')
flattened_info =df5['top'].apply(pd.Series)

# Restructure the DataFrame to have each key as a column
car_overview = flattened_info.pivot_table(index=flattened_info.groupby('key').cumcount(), 
                            columns='key', 
                            values='value', 
                            aggfunc='first')

print("Len of result", len(car_overview))
car_overview
# Out:
# Len of result 1419
# key  Engine Displacement Fuel Type     Insurance Validity  Kms Driven  \
# 0                 998 cc    Petrol  Third Party insurance  20,000 Kms
# 1                1196 cc    Petrol          Comprehensive  20,687 Kms
# 2                 999 cc    Petrol  Third Party insurance  30,000 Kms
# 3                1086 cc    Petrol          Comprehensive  59,247 Kms
# 4                1199 cc    Petrol  Third Party insurance  50,000 Kms
# ...                  ...       ...                    ...         ...
# 1414             1197 cc    Petrol  Third Party insurance  42,891 Kms
# 1415             1461 cc    Diesel  Third Party insurance  59,100 Kms
# 1416             1198 cc    Petrol          Not Available  55,913 Kms
# 1417             1968 cc    Diesel          Comprehensive  65,000 Kms
# 1418             1995 cc    Diesel          Comprehensive  60,000 Kms
#
# key     Ownership   RTO Registration Year    Seats Transmission  \
# ...

# %%
#Checking for null records 
car_overview.isnull().sum()
# Out:
# key
# Engine Displacement      0
# Fuel Type                0
# Insurance Validity       0
# Kms Driven               0
# Ownership               22
# RTO                    110
# Registration Year       22
# Seats                    0
# Transmission             0
# Year of Manufacture      0
# dtype: int64

# %%
df2
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
#Splitting data in the new car features column into specific columns

#list to hold the feature lists
feature_lists = []
data_list = []

# Iterate through each record in the specified column containing the JSON data
for json_str in df2['new_car_feature']:

    json_str = json_str.replace("'",'"')
    # Parse the JSON
    data = json.loads(json_str)

    data_list = []
    for i in data['data']:
        data_list += i['list']
    
    # Extract feature values
    features = [item['value'] for item in data_list]
    
    # Append the feature list to the main list
    feature_lists.append(features)

# Create a new DataFrame with the extracted features
df_features = pd.DataFrame({'Features': feature_lists})

# Display the new DataFrame
print(df_features)
# Out:
#                                                Features
# 0     [Power Steering, Power Windows Front, Power Wi...
# 1     [Low Fuel Warning Light, Accessory Power Outle...
# 2     [Power Steering, Power Windows Front, Power Wi...
# 3     [Power Steering, Power Windows Front, Power Wi...
# 4     [Power Steering, Power Windows Front, Power Wi...
# ...                                                 ...
# 1414  [Power Steering, Power Windows Front, Power Wi...
# 1415  [Power Steering, Power Windows Front, Power Wi...
# 1416  [Power Steering, Power Windows Front, Power Wi...
# 1417  [Power Steering, Power Windows Front, Power Wi...
# 1418  [Power Steering, Power Windows Front, Power Wi...
#
# [1419 rows x 1 columns]

# %%
# splitting data in the new car Specifications column into specific columns
# list to hold the feature lists
specifications_list = []
data_list = []

# Iterate through each record in the specified column containing the JSON data
for json_str in df2['new_car_specs']:

    json_str = json_str.replace("'",'"')
    # Parse the JSON
    data = json.loads(json_str)

    # Add Top Specs to data_list
    data_list += data['top']

    for i in data['data']:
        data_list += i['list']
    
    # Extract feature values
    specifications = {item['key']: item['value'] for item in data_list}
    
    # Append the feature list to the main list
    specifications_list.append(specifications)

#Create a new DataFrame with the extracted features
df_specifications = pd.DataFrame(specifications_list)

# Display the new DataFrame
print(df_specifications)
# Out:
#        Engine          Max Power   Torque Wheel Size Seats   Color  \
# 0      998 CC  118.36bhp@6000rpm    172nm         16     5   Black
# 1     1196 CC      73bhp@6000rpm    101Nm         16     7    Grey
# 2      999 CC   98.63bhp@5000rpm    160Nm         16     5  Others
# 3     1086 CC   68.05bhp@5500rpm  99.04Nm         16     5  Silver
# 4     1199 CC    88.7bhp@6000rpm    110Nm         15     5  Others
# ...       ...                ...      ...        ...   ...     ...
# 1414  1197 CC   81.80bhp@6000rpm    113Nm         17     5    Blue
# 1415  1461 CC    83.8bhp@3750rpm    200Nm         16     5  Orange
# 1416  1198 CC   108.5bhp@5000rpm    170Nm         16     5   White
# 1417  1968 CC     141bhp@4000rpm    340Nm         18     5    Grey
# 1418  1995 CC     188bhp@4000rpm    400Nm         18     5   White
#
#                                    Engine Type Displacement  \
# 0                     Smartstream G1.0 T - GDi          998
# ...

# %%
# Adding up all data columns to singe dataframe
Chennai_cars = pd.concat([new_car_detail,car_overview,df_features,df_specifications],axis=1)
col_list = Chennai_cars.columns.to_list()
Chennai_cars.columns
# print(len(col_list))
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText',
#        'Engine Displacement', 'Fuel Type', 'Insurance Validity', 'Kms Driven',
#        'Ownership', 'RTO', 'Registration Year', 'Seats', 'Transmission',
#        'Year of Manufacture', 'Features', 'Engine', 'Max Power', 'Torque',
#        'Wheel Size', 'Seats', 'Color', 'Engine Type', 'Displacement',
#        'Max Torque', 'No of Cylinder', 'Values per Cylinder',
#        'Fuel Suppy System', 'Turbo Charger', 'Length', 'Width', 'Height',
#        'Wheel Base', 'Kerb Weight', 'Gear Box', 'Drive Type',
#        'Seating Capacity', 'Steering Type', 'Front Brake Type',
#        'Rear Brake Type', 'Tyre Type', 'Alloy Wheel Size', 'No Door Numbers',
#        'Cargo Volumn', 'Mileage', 'Value Configuration', 'Compression Ratio',
# ...

# %%
#Checking for null records 
Chennai_cars.isnull().sum()
# Out:
# it                           0
# ft                           0
# bt                           0
# km                           0
# transmission                 0
#                             ..
# Turning Radius               1
# Top Speed                    1
# Acceleration                 1
# BoreX Stroke                 2
# Ground Clearance Unladen    15
# Length: 68, dtype: int64

# %%
Chennai_cars.to_csv(r'C:\Users\hbhat\OneDrive\Desktop\VScode\Capstoneproject3\Chennai.csv',encoding='utf-8',index=False)
