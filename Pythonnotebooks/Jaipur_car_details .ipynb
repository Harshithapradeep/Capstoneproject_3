# %%
# Loading the csv file to pandas dataframe
import pandas as pd
df=pd.read_excel(r'C:\Users\hbhat\OneDrive\Desktop\VScode\Capstoneproject3\Datset\jaipur_cars.xlsx')
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1115  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1116  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1117  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1118  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1119  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1115  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1116  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1117  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1118  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1119  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1115  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1116  {'heading': 'Features', 'top': [{'value': 'Low...
# 1117  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1118  {'heading': 'Features', 'top': [{'value': 'Low...
# 1119  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1115  {'heading': 'Specifications', 'top': [{'key': ...
# 1116  {'heading': 'Specifications', 'top': [{'key': ...
# 1117  {'heading': 'Specifications', 'top': [{'key': ...
# 1118  {'heading': 'Specifications', 'top': [{'key': ...
# 1119  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1115  https://www.cardekho.com/used-car-details/used...
# 1116  https://www.cardekho.com/used-car-details/used...
# 1117  https://www.cardekho.com/used-car-details/used...
# 1118  https://www.cardekho.com/used-car-details/used...
# 1119  https://www.cardekho.com/used-car-details/used...
#
# [1120 rows x 5 columns]

# %%
# Data processing of unstructured data into structured data by splitting data in the new car detail column into specific columns
df2 = df.copy()
df2['new_car_detail'] = df2['new_car_detail'].apply(lambda x : dict(eval(x)))
new_car_detail = df2['new_car_detail'].apply(pd.Series)
print("Length of new_car_detail", len(new_car_detail))
new_car_detail
# Out:
# Length of new_car_detail 1120
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  centralVariantId  \
# 0       Hyundai        Hyundai i20       2015              1487
# 1        Maruti       Maruti Swift       2012             10403
# 2        Maruti     Maruti Celerio       2016              3982
# 3       Hyundai  Hyundai Grand i10       2017              5602
# 4        Maruti     Maruti Wagon R       2016              4319
# ...         ...                ...        ...               ...
# 1115  Chevrolet     Chevrolet Beat       2011               438
# 1116     Maruti        Maruti Alto       2007              3917
# 1117    Renault      Renault Kiger       2022              8350
# 1118     Maruti        Maruti Alto       2009              3904
# 1119     Maruti      Maruti Baleno       2018              3962
#
#                variantName        price priceActual priceSaving  \
# 0            Asta 1.4 CRDi  ₹ 5.10 Lakh
# 1                      VXI  ₹ 3.81 Lakh
# 2                   VXI AT  ₹ 3.20 Lakh
# 3     1.2 Kappa Magna BSIV  ₹ 4.20 Lakh
# 4                  AMT VXI  ₹ 3.50 Lakh
# ...                    ...          ...         ...         ...
# 1115                    LT  ₹ 1.08 Lakh
# 1116                   STD  ₹ 1.05 Lakh
# 1117                   RXZ  ₹ 8.50 Lakh
# 1118                   Std     ₹ 1 Lakh
# 1119             1.2 Delta     ₹ 5 Lakh
#
#      priceFixedText                                       trendingText
# 0              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 2              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 3              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 4              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# ...             ...                                                ...
# 1115           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1116           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1117           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1118           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1119           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
#
# [1120 rows x 17 columns]

# %%
new_car_detail.isnull().sum() # check for null records
# Out:
# it                     0
# ft                     0
# bt                     0
# km                     0
# transmission           0
# ownerNo                0
# owner                  0
# oem                    0
# model                  0
# modelYear              0
# centralVariantId       0
# variantName            0
# price                  0
# priceActual            0
# priceSaving            0
# priceFixedText      1120
# trendingText           0
# dtype: int64

# %%
#  Data processing of unstructured data into structured data by splitting data in the new car overview column into specific columns
df2 = df.copy()
df2['new_car_overview'] = df2['new_car_overview'].apply(lambda x : dict(eval(x)))
df4 = df2['new_car_overview'].apply(pd.Series)

df5 = df4.explode('top')
flattened_info =df5['top'].apply(pd.Series)

# Restructure the DataFrame to have each key as a column
car_overview = flattened_info.pivot_table(index=flattened_info.groupby('key').cumcount(), 
                            columns='key', 
                            values='value', 
                            aggfunc='first')

print("Len of result", len(car_overview))
car_overview
# Out:
# Len of result 1120
# key  Engine Displacement Fuel Type     Insurance Validity    Kms Driven  \
# 0                1396 cc    Diesel  Third Party insurance  1,20,000 Kms
# 1                1197 cc    Petrol            Third Party    66,951 Kms
# 2                 998 cc    Petrol  Third Party insurance    80,000 Kms
# 3                1197 cc    Petrol  Third Party insurance    44,392 Kms
# 4                 998 cc    Petrol  Third Party insurance    40,000 Kms
# ...                  ...       ...                    ...           ...
# 1115             1199 cc    Petrol  Third Party insurance    70,000 Kms
# 1116              796 cc    Petrol  Third Party insurance    20,000 Kms
# 1117              999 cc    Petrol  Third Party insurance    40,000 Kms
# 1118              796 cc    Petrol  Third Party insurance    80,000 Kms
# 1119             1197 cc    Petrol  Third Party insurance           NaN
#
# key      Ownership   RTO Registration Year    Seats Transmission  \
# 0     Second Owner  RJ13              2015  5 Seats       Manual
# 1      First Owner  RJ14          Jan 2012  5 Seats       Manual
# 2     Second Owner  RJ14              2016  5 Seats    Automatic
# 3      First Owner  RJ14          Apr 2017  5 Seats       Manual
# 4      First Owner  RJ14              2016  5 Seats    Automatic
# ...            ...   ...               ...      ...          ...
# 1115   First Owner   NaN               NaN  5 Seats       Manual
# 1116   First Owner   NaN               NaN  5 Seats       Manual
# 1117   First Owner   NaN               NaN  5 Seats       Manual
# 1118   First Owner   NaN               NaN  5 Seats       Manual
# 1119           NaN   NaN               NaN      NaN       Manual
#
# key  Year of Manufacture
# 0                   2015
# 1                   2012
# 2                   2016
# 3                   2017
# 4                   2016
# ...                  ...
# 1115                 NaN
# 1116                 NaN
# 1117                 NaN
# 1118                 NaN
# 1119                 NaN
#
# [1120 rows x 10 columns]

# %%
df2
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1115  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1116  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1117  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1118  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1119  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1115  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1116  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1117  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1118  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1119  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1115  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1116  {'heading': 'Features', 'top': [{'value': 'Low...
# 1117  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1118  {'heading': 'Features', 'top': [{'value': 'Low...
# 1119  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1115  {'heading': 'Specifications', 'top': [{'key': ...
# 1116  {'heading': 'Specifications', 'top': [{'key': ...
# 1117  {'heading': 'Specifications', 'top': [{'key': ...
# 1118  {'heading': 'Specifications', 'top': [{'key': ...
# 1119  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1115  https://www.cardekho.com/used-car-details/used...
# 1116  https://www.cardekho.com/used-car-details/used...
# 1117  https://www.cardekho.com/used-car-details/used...
# 1118  https://www.cardekho.com/used-car-details/used...
# 1119  https://www.cardekho.com/used-car-details/used...
#
# [1120 rows x 5 columns]

# %%
#  Splitting data in the new car features column into specific columns

import json
df2 = df.copy() 

# list to hold the feature lists
feature_lists = []
data_list = []

# Iterate through each record in the specified column containing the JSON data
for json_str in df2['new_car_feature']:

    json_str = json_str.replace("'",'"')
    # Parse the JSON
    data = json.loads(json_str)

    data_list = []
    for i in data['data']:
        data_list += i['list']
    
    # Extract feature values
    features = [item['value'] for item in data_list]
    
    # Append the feature list to the main list
    feature_lists.append(features)

# Create a new DataFrame with the extracted features
df_features = pd.DataFrame({'Features': feature_lists})

# Display the new DataFrame
print(df_features)
# Out:
#                                                Features
# 0     [Power Steering, Power Windows Front, Power Wi...
# 1     [Power Steering, Power Windows Front, Power Wi...
# 2     [Power Steering, Power Windows Front, Power Wi...
# 3     [Power Steering, Power Windows Front, Power Wi...
# 4     [Power Steering, Power Windows Front, Power Wi...
# ...                                                 ...
# 1115  [Power Steering, Power Windows Front, Power Wi...
# 1116  [Low Fuel Warning Light, Electronic Multi Trip...
# 1117  [Power Steering, Power Windows Front, Power Wi...
# 1118  [Low Fuel Warning Light, Electronic Multi Trip...
# 1119  [Power Steering, Power Windows Front, Power Wi...
#
# [1120 rows x 1 columns]

# %%
#  Splitting data in the new car features column into specific columns

import json
df2 = df.copy() 

# list to hold the feature lists
specifications_list = []
data_list = []

# Iterate through each record in the specified column containing the JSON data
for json_str in df2['new_car_specs']:

    json_str = json_str.replace("'",'"')
    # Parse the JSON
    data = json.loads(json_str)

    # Add Top Specs to data_list
    data_list += data['top']

    for i in data['data']:
        data_list += i['list']
    
    # Extract feature values
    specifications = {item['key']: item['value'] for item in data_list}
    
    # Append the feature list to the main list
    specifications_list.append(specifications)

# Create a new DataFrame with the extracted features
df_specifications = pd.DataFrame(specifications_list)

# Display the new DataFrame
print(df_specifications)
# Out:
#          Mileage   Engine         Max Power    Torque Wheel Size Seats  \
# 0     22.54 kmpl  1396 CC  88.73bhp@4000rpm   219.7Nm         16     5
# 1     22.38 kmpl  1197 CC  88.50bhp@6000rpm     113Nm         16     5
# 2      23.1 kmpl   998 CC  67.04bhp@6000rpm      90Nm         16     5
# 3      18.9 kmpl  1197 CC  81.86bhp@6000rpm  113.75nm         16     5
# 4     20.51 kmpl   998 CC     67bhp@6000rpm      90Nm         16     5
# ...          ...      ...               ...       ...        ...   ...
# 1115   18.6 kmpl  1199 CC   79.4bhp@6200rpm     108Nm         14     5
# 1116   19.7 kmpl   796 CC   46.3bhp@6200rpm      62Nm         12     5
# 1117  19.17 kmpl   999 CC  71.01bhp@6250rpm      96Nm         16     5
# 1118   19.7 kmpl   796 CC   46.3bhp@6200rpm      62Nm         12     5
# 1119   21.4 kmpl  1197 CC   83.1bhp@6000rpm     115Nm         12     5
#
#        Color               Engine Type Displacement            Max Torque  \
# 0     Others     U2 CRDI Diesel Engine         1396  219.7Nm@1500-2750rpm
# 1      White         K Series Dual jet         1197         113Nm@4400rpm
# 2     Others               K10B Engine          998          90Nm@3500rpm
# 3     Silver  Kappa VTVT Petrol Engine         1197      113.75nm@4000rpm
# 4     Silver        K10B Petrol Engine          998          90Nm@3500rpm
# ...      ...                       ...          ...                   ...
# 1115  Others           Smartech Engine         1199         108Nm@4400rpm
# 1116  Others            In-Line Engine          796          62Nm@3000rpm
# 1117  Others               1.0L energy          999          96Nm@3500rpm
# 1118  Others            In-Line Engine          796          62Nm@3000rpm
# 1119  Others         VVT Petrol Engine         1197         115Nm@4000rpm
#
#       ...  Top Speed   Acceleration         Tyre Type Alloy Wheel Size  \
# 0     ...   180 Kmph   11.9 Seconds          Tubeless               16
# 1     ...   180 Kmph   11.9 Seconds  Radial, Tubeless               16
# 2     ...   150 Kmph  15.05 Seconds  Tubeless, Radial               16
# 3     ...   165 Kmph   12.9 Seconds          Tubeless               16
# 4     ...   152 kmph   18.6 Seconds    Tubeless Tyres               16
# ...   ...        ...            ...               ...              ...
# 1115  ...   182 Kmph   13.5 Seconds   Tubeless,Radial               14
# 1116  ...   137km/hr   17.7 seconds   Tubeless,Radial               12
# 1117  ...   137km/hr   17.7 seconds  Tubeless, Radial               16
# 1118  ...   137km/hr   17.7 seconds   Tubeless,Radial               12
# 1119  ...   180 Kmph  12.36 seconds   Tubeless,Radial               12
#
#      No Door Numbers Cargo Volumn Gross Weight    BoreX Stroke  \
# 0                  5   295-litres          NaN             NaN
# 1                  5          268         1335             NaN
# 2                  5   235-litres       1250kg      73 X 82 mm
# 3                  5          256       1250kg      73 X 82 mm
# 4                  5   180-liters       1350kg      69 x 72 mm
# ...              ...          ...          ...             ...
# 1115               5   170-litres      1740kgs  73.5 X 88.3 mm
# 1116               5   170-litres       1140kg  68.5 x 72.0 mm
# 1117               5          405       1140kg  68.5 x 72.0 mm
# 1118               5          405       1140kg  68.5 x 72.0 mm
# 1119               5   339-litres       1340kg  68.5 x 72.0 mm
#
#      Compression Ratio Ground Clearance Unladen
# 0                  NaN                      NaN
# 1                  NaN                      NaN
# 2               11.0:1                      NaN
# 3               11.0:1                      NaN
# 4               11.0:1                      NaN
# ...                ...                      ...
# 1115            16.0:1                      160
# 1116            16.0:1                      160
# 1117            16.0:1                      160
# 1118            16.0:1                      160
# 1119            16.0:1                      160
#
# [1120 rows x 40 columns]

# %%
# Adding up all data columns to singe dataframe 
Jaipur_cars = pd.concat([new_car_detail,car_overview,df_features,df_specifications],axis=1)
col_list =Jaipur_cars.columns.to_list()
Jaipur_cars.columns
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText',
#        'Engine Displacement', 'Fuel Type', 'Insurance Validity', 'Kms Driven',
#        'Ownership', 'RTO', 'Registration Year', 'Seats', 'Transmission',
#        'Year of Manufacture', 'Features', 'Mileage', 'Engine', 'Max Power',
#        'Torque', 'Wheel Size', 'Seats', 'Color', 'Engine Type', 'Displacement',
#        'Max Torque', 'No of Cylinder', 'Values per Cylinder',
#        'Value Configuration', 'Fuel Suppy System', 'Turbo Charger',
#        'Super Charger', 'Length', 'Width', 'Height', 'Wheel Base',
#        'Front Tread', 'Rear Tread', 'Kerb Weight', 'Gear Box', 'Drive Type',
#        'Seating Capacity', 'Steering Type', 'Turning Radius',
#        'Front Brake Type', 'Rear Brake Type', 'Top Speed', 'Acceleration',
#        'Tyre Type', 'Alloy Wheel Size', 'No Door Numbers', 'Cargo Volumn',
#        'Gross Weight', 'BoreX Stroke', 'Compression Ratio',
#        'Ground Clearance Unladen'],
#       dtype='object')

# %%
# Loading the required data to csv file for each cities
Jaipur_cars.to_csv(r'C:\Users\hbhat\OneDrive\Desktop\VScode\Capstoneproject3\Jaipur.csv',encoding='utf-8',index=False)
